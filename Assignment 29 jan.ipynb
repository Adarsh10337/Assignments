# %%
Q1) Who developed Python programming language?
Ans) Guido van Rossum

Q2) Which type of programming does Python support?
Ans) Imperative, Functional and object-oriented

Q3) Is Python case sensitive while dealing with identifiers?
Ans) Yes, Python is case sensitive

Q4) What is the correct extension of the Python file?
Ans) dot py(.py) entension

Q5) Is Python code compiled or interpreted?
Ans) Interpreted

Q6) Name a few blocks of code used to define in Python language?
Ans) Module, classes, function body

Q7) State a character used to give single-line comments in Python?
Ans) # hash symbol is for single line comment

Q8) Mention functions which can help us to find the version of python that we are currently working on?
Ans) sys. version, - V command also

Q9) Python supports the creation of anonymous functions at runtime, using a construct called?
Ans) Lambda function

Q10) What does pip stand for python?
Ans) Preffered installer program, these are the commands that helps us for installing extensions, modules, libraries etc

Q11) Mention a few built-in functions in python?
Ans) print( ) function.
     type( ) function.
     input( ) function.
     dir()

Q12) What is the maximum possible length of an identifier in Python?
Ans) An identifier can have a maximum length of 79 characters in Python

Q13) What are the benefits of using Python?
Ans) Data science.
     Scientific and mathematical computing.
     Web development.
     Finance and trading.
     System automation and administration.
     Computer graphics.
     Basic game development.
     Security and penetration testing

Q14) How is memory managed in Python?
Ans) Memory managed as a heap data structure

Q15) How to install Python on Windows and set path variables?
Ans) from python.org it can be downloaded and also from the other sites and while installing the python will ask for the path where we have to store the python.

Q16) How to install Python on Windows and set path variables?
Ans) Indentation is must in every program including the python also. it will be used to defines the code block.
