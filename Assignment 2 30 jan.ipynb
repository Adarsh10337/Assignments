# %%
(Answer)
Q1)------------------------------------

Per = int(input("Enter your percentage:"))
if Per > 90:
    print("A")
elif Per > 80 and Per <= 90:
    print("B")
elif Per >= 60 and Per <= 80:
    print("C")
elif Per < 60:
    print("D")
    
Q2)  ----------------------------

price = int(input("Enter Bike price:"))
if price <= 50000:
    print("5%")
elif price > 50000 and Per <= 100000:
    print("10%")
elif price > 100000:
    print("15%")
    
Q3)  ----------------------------

Place = input("Enter your City name:")
if Place == "Delhi":
    print("Red fort")
elif Place == "Agra":
    print("Taj Mahal")
elif Place == "Jaipur":
    print("Jal Mahal")
    
Q4) --------------------

num = int(input("enter your number:"))
count = 0
while num > 10:
    num = num / 3
    count += 1
print(count)

Q5) -----------------------

The while loop in Python is used when you want to repeatedly execute a block of code as long as a certain condition is met. The code block inside the loop will be executed as many times as it takes for the condition to become false.

The general syntax of a while loop in Python is:
    while condition:
    # code block to be executed
    # update the condition

    For example, let's say you want to print the numbers from 1 to 10. You can use a while loop for this:
    counter = 1
    while counter <= 10:
        print(counter)
        counter += 1

Q6) ----------------------

Pattern 1:
    
i = 1
while i <= 5:
    j = 1
    while j <= i:
        print("*", end="")
        j = j + 1
    print("")
    i = i + 1

    
OUTPUT:

*
**
***
****
*****


Pattern 2:

i = 5
while i >= 1:
    j = 1
    while j <= i:
        print("*", end="")
        j = j + 1
    print("")
    i = i - 1


OUTPUT:

*****
****
***
**
*


Pattern 3:
    
i = 1
while i <= 5:
    j = 1
    while j <= 5-i:
        print(" ", end="")
        j = j + 1
    k = 1
    while k <= i:
        print("*", end="")
        k = k + 1
    print("")
    i = i + 1

OUTPUT:
    
    *
   **
  ***
 ****
*****


Q7) ------------------

i = 10
while i > 0:
    print(i)
    i = i - 1
    
Q8) ---------------------

Same as 7
